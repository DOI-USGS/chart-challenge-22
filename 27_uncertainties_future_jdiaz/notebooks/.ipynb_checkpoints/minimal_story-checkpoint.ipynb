# %% [markdown]
# ### Intro
#
# Last year, we provided forecasts of stream temperature to reservoir managers in the Delaware River Basin. These forecasts utilized weather ensembles and Monte Carlo dropout to provide probabilistic forecasts - that is, we predict the distribution of possible stream temperatures, not just one estimate of stream temperature.
#
# <br><br><br>
#
# One example of that can be seen here:
#
# ![PlainForecast-5.png](attachment:PlainForecast-5.png)

# %% [markdown]
# You can see that the real temperature that occured at this time falls into our predicted distribution.
#
# <br><br><br>
#
# One method we used to improve these forecasts was DA which uses recently observed temperatures to correct/adjust our model's forecast. When we use DA along the previously observed days, this is what our forecast is adjusted to 1 day prior to the observation:
#
# ![BothForecasts-4.png](attachment:BothForecasts-4.png)

# %% [markdown]
# As you can see, this adjusted distribution is pretty similar to the previous one because the original forecast did a pretty good job, but now we have assigned a higher probability to the values closer to where the observation ended up occurring at.
#
# <br><br><br>
#
# One way to visualize what was adjusted is to display the difference between these distributions. Like this:
#
# ![DA_GoodShift-6.png](attachment:DA_GoodShift-6.png)

# %% [markdown]
# Here, the purple shade represents the location and placement of probability that was adjusted away while the orange is what replaced it. As we would like, values further from the observation were adjusted away in favor of those closer to it.
#
# <br><br><br>

# %% [markdown]
# Sometimes, assimilating recent observations shifts the distribution to a better location. Other times, the location of the distribution stays largely the same, but we increase confidence towards the center.
#
# ![DA_ConfidBoost-5.png](attachment:DA_ConfidBoost-5.png)

# %% [markdown]
# <br><br><br>
#
# And sometimes the adjustments that DA makes lead to a worse forecast (but thankfully this is not generally the case)
#
# ![DA_BadShift-5.png](attachment:DA_BadShift-5.png)

# %% [markdown]
# <br><br><br>
#
# This is what these differences in forecast look like if we view them over a random week with our 7-day ahead forecasts.
#
# ![13-6.png](attachment:13-6.png)
